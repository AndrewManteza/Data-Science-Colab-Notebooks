# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewManteza/Data-Science-Colab-Notebooks/blob/main/Manteza_MidtermExam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PART 1 Online Retail

# %% [markdown]
# A.

# %%
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile

retail_frame = pd.read_excel("/content/Online Retail.xlsx")

# %%
print (retail_frame)
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# B.

# %%
retail_frame.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
retail_frame.mode()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    573585    85123A  ...    17841.0  United Kingdom
#
# [1 rows x 8 columns]

# %% [markdown]
# C.

# %%
mean_value=retail_frame['CustomerID'].mean()
mode_value=retail_frame['Description'].mode()
retail_frame.fillna(mean_value)
retail_frame.fillna(mode_value)
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 0         536365    85123A  ...    17850.0  United Kingdom
# 1         536365     71053  ...    17850.0  United Kingdom
# 2         536365    84406B  ...    17850.0  United Kingdom
# 3         536365    84029G  ...    17850.0  United Kingdom
# 4         536365    84029E  ...    17850.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 541904    581587     22613  ...    12680.0          France
# 541905    581587     22899  ...    12680.0          France
# 541906    581587     23254  ...    12680.0          France
# 541907    581587     23255  ...    12680.0          France
# 541908    581587     22138  ...    12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# D.

# %%
print(retail_frame.describe(), '\n')
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# E.

# %%
retail_frame20 = retail_frame.head(20)
print(retail_frame20)
# Out:
#    InvoiceNo StockCode  ... CustomerID         Country
# 0     536365    85123A  ...    17850.0  United Kingdom
# 1     536365     71053  ...    17850.0  United Kingdom
# 2     536365    84406B  ...    17850.0  United Kingdom
# 3     536365    84029G  ...    17850.0  United Kingdom
# 4     536365    84029E  ...    17850.0  United Kingdom
# 5     536365     22752  ...    17850.0  United Kingdom
# 6     536365     21730  ...    17850.0  United Kingdom
# 7     536366     22633  ...    17850.0  United Kingdom
# 8     536366     22632  ...    17850.0  United Kingdom
# 9     536367     84879  ...    13047.0  United Kingdom
# 10    536367     22745  ...    13047.0  United Kingdom
# 11    536367     22748  ...    13047.0  United Kingdom
# 12    536367     22749  ...    13047.0  United Kingdom
# 13    536367     22310  ...    13047.0  United Kingdom
# 14    536367     84969  ...    13047.0  United Kingdom
# 15    536367     22623  ...    13047.0  United Kingdom
# ...

# %% [markdown]
# F.

# %%
retail_sample_frame = retail_frame.sample(frac=0.3)
retail_sample_frame
# Out:
#        InvoiceNo StockCode  ... CustomerID         Country
# 401726    571441    84596B  ...    14096.0  United Kingdom
# 480420    577302     48138  ...    17904.0  United Kingdom
# 124507    546980     21843  ...    13591.0  United Kingdom
# 327191    565618     22469  ...    15974.0  United Kingdom
# 463217    576055     21889  ...    15449.0  United Kingdom
# ...          ...       ...  ...        ...             ...
# 535733    581217     22875  ...        NaN  United Kingdom
# 345720    567175     22188  ...    13067.0  United Kingdom
# 180394    552316     23298  ...    15674.0  United Kingdom
# 175576    551966     21733  ...    15356.0  United Kingdom
# 57162     541133     22188  ...        NaN  United Kingdom
#
# [162573 rows x 8 columns]

# %% [markdown]
# G.

# %%
retail_sample_frame.Description.unique()
# Out:
# array(['SMALL DOLLY MIX DESIGN ORANGE BOWL', 'DOORMAT UNION FLAG',
#        'RED RETROSPOT CAKE STAND', ..., 'GOLDIE LOOKING MIRROR',
#        'GLASS BEAD HOOP EARRINGS GREEN', 'WAY OUT METAL SIGN '],
#       dtype=object)

# %% [markdown]
# H.

# %%
print(retail_sample_frame.groupby([pd.Grouper(key = 'InvoiceDate', freq='M'),'Quantity']).sum())
# Out:
#                       UnitPrice  CustomerID
# InvoiceDate Quantity
# 2010-12-31  -500           2.55     16013.0
#             -300           0.72     16013.0
#             -177           0.00         0.0
#             -150           0.00         0.0
#             -144           0.72     16546.0
# ...                         ...         ...
# 2011-12-31   388           1.95     17857.0
#              400           1.79     15769.0
#              620           2.55     16000.0
#              800           0.25     17857.0
#              960           3.39     16210.0
#
# [1730 rows x 2 columns]

# %% [markdown]
# I.

# %%
print(retail_sample_frame.groupby([pd.Grouper(key='InvoiceDate', freq='W'), 'Description']).sum().head(50))
# Out:
#                                                  Quantity  ...  CustomerID
# InvoiceDate Description                                    ...
# 2010-12-05   SET 2 TEA TOWELS I LOVE LONDON            17  ...     68982.0
#             10 COLOUR SPACEBOY PEN                     50  ...     29912.0
#             12 DAISY PEGS IN WOOD BOX                   1  ...     17920.0
#             12 PENCIL SMALL TUBE WOODLAND              50  ...     64030.0
#             12 PENCILS SMALL TUBE RED RETROSPOT       244  ...     98445.0
#             12 PENCILS SMALL TUBE SKULL                36  ...     50531.0
#             12 PENCILS TALL TUBE RED RETROSPOT         13  ...     27586.0
#             12 PENCILS TALL TUBE WOODLAND              17  ...     29721.0
#             12 RED ROSE PEG PLACE SETTINGS              3  ...     33192.0
#             15CM CHRISTMAS GLASS BALL 20 LIGHTS         8  ...     27870.0
#             20 DOLLY PEGS RETROSPOT                    26  ...     27788.0
# ...

# %% [markdown]
# J.

# %%
group_by_country = retail_sample_frame

print(group_by_country.groupby([pd.Grouper(key='Country')]).UnitPrice.sum())
# Out:
# Country
# Australia                 1225.740
# Austria                    428.870
# Bahrain                     15.210
# Belgium                   2256.010
# Brazil                      60.690
# Canada                     136.150
# Channel Islands            986.830
# Cyprus                     999.550
# Czech Republic              20.240
# Denmark                    488.050
# EIRE                     12024.770
# European Community          72.750
# Finland                    930.040
# France                   13830.010
# Germany                  11269.590
# Greece                     259.540
# Hong Kong                 3402.690
# Iceland                    140.120
# Israel                     409.320
# Italy                     1171.850
# Japan                      232.470
# Lebanon                     82.300
# Lithuania                   30.900
# Malta                      130.450
# Netherlands               1805.660
# Norway                    2666.640
# ...

# %% [markdown]
# K.

# %%
group_by_description = retail_sample_frame
print(group_by_description.groupby([pd.Grouper(key='Description')]).UnitPrice.sum())
# Out:
# Description
#  4 PURPLE FLOCK DINNER CANDLES     29.63
#  50'S CHRISTMAS GIFT BAG LARGE     71.97
#  DOLLY GIRL BEAKER                 55.37
#  I LOVE LONDON MINI BACKPACK      128.22
#  NINE DRAWER OFFICE TIDY          235.98
#                                    ...
# wrong barcode                       0.00
# wrong code                          0.00
# wrongly coded 20713                 0.00
# wrongly marked carton 22804         0.00
# wrongly sold as sets                0.00
# Name: UnitPrice, Length: 3823, dtype: float64

# %% [markdown]
# Part 2 Family Income and Expenditure

# %% [markdown]
# A.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

family_frame = pd.read_csv("/content/Family Income and Expenditure - Family Income and Expenditure.csv")

# %% [markdown]
# B.

# %%
print(family_frame.isnull().sum())
# Out:
# Total Household Income                              0
# Region                                              0
# Total Food Expenditure                              0
# Main Source of Income                               0
# Agricultural Household indicator                    0
# Bread and Cereals Expenditure                      15
# Total Rice Expenditure                              0
# Meat Expenditure                                    0
# Total Fish and  marine products Expenditure         0
# Fruit Expenditure                                   0
# Vegetables Expenditure                              0
# Restaurant and hotels Expenditure                  19
# Alcoholic Beverages Expenditure                     0
# Tobacco Expenditure                                 0
# Clothing, Footwear and Other Wear Expenditure       0
# Housing and water Expenditure                       0
# Imputed House Rental Value                          0
# ...

# %% [markdown]
# C.

# %%
mean_value=family_frame['Bread and Cereals Expenditure'].mean()
mean_value=family_frame['Restaurant and hotels Expenditure'].mean()
mean_value=family_frame['Household Head Age'].mean()
mode_value=family_frame['Household Head Occupation'].mode()
mode_value=family_frame['Household Head Class of Worker'].mode()
family_frame.fillna(mean_value)
family_frame.fillna(mode_value)
# Out:
#        Total Household Income  ... Number of Motorcycle/Tricycle
# 0                      480332  ...                             1
# 1                      198235  ...                             2
# 2                       82785  ...                             0
# 3                      107589  ...                             0
# 4                      189322  ...                             1
# ...                       ...  ...                           ...
# 41539                  119773  ...                             0
# 41540                  137320  ...                             0
# 41541                  133171  ...                             0
# 41542                  129500  ...                             0
# 41543                  128598  ...                             0
#
# [41544 rows x 60 columns]

# %% [markdown]
# D.

# %%
family_frame.head(20)
# Out:
#     Total Household Income  ... Number of Motorcycle/Tricycle
# 0                   480332  ...                             1
# 1                   198235  ...                             2
# 2                    82785  ...                             0
# 3                   107589  ...                             0
# 4                   189322  ...                             1
# 5                   152883  ...                             1
# 6                   198621  ...                             1
# 7                   134961  ...                             1
# 8                   171152  ...                             0
# 9                   625753  ...                             0
# 10                  147005  ...                             1
# 11                  253130  ...                             0
# 12                  101111  ...                             0
# 13                  128214  ...                             1
# ...

# %% [markdown]
# E.

# %%
family_sample_frame =family_frame.sample(frac=0.2)
family_sample_frame
# Out:
#        Total Household Income  ... Number of Motorcycle/Tricycle
# 2884                   232535  ...                             1
# 40685                  158033  ...                             0
# 36478                  184260  ...                             0
# 22235                  481396  ...                             1
# 33672                  145915  ...                             0
# ...                       ...  ...                           ...
# 32734                  116985  ...                             0
# 38201                  197928  ...                             0
# 39346                  183718  ...                             0
# 11741                  143531  ...                             0
# 12484                  100559  ...                             0
#
# [8309 rows x 60 columns]

# %% [markdown]
# F.

# %%
results = family_sample_frame['Household Head Age']
bins = [0,25,50,75,100]
Bin1 = pd.cut(results, bins)
names = ['0-25','26-50','51-75','76-100']
Bin1 = pd.cut(results, bins, labels=names)

# %% [markdown]
# G

# %%
print(pd.value_counts(Bin1), '\n')
# Out:
# 26-50     3866
# 51-75     3791
# 76-100     453
# 0-25       186
# Name: Household Head Age, dtype: int64

# %% [markdown]
# H.

# %%
result5 = pd.cut(family_sample_frame['Household Head Age'], bins=5)

# %% [markdown]
# I.

# %%
print(result5)
# Out:
# 2884      (45.6, 63.4]
# 40685     (45.6, 63.4]
# 36478     (45.6, 63.4]
# 22235     (63.4, 81.2]
# 33672     (27.8, 45.6]
#              ...
# 32734     (45.6, 63.4]
# 38201     (45.6, 63.4]
# 39346     (45.6, 63.4]
# 11741    (9.911, 27.8]
# 12484    (9.911, 27.8]
# Name: Household Head Age, Length: 8309, dtype: category
# Categories (5, interval[float64]): [(9.911, 27.8] < (27.8, 45.6] < (45.6, 63.4] < (63.4, 81.2] <
#                                     (81.2, 99.0]]

# %% [markdown]
# J.

# %%
family_sample_frame_copy = family_sample_frame

# %% [markdown]
# K.

# %%
family_sample_frame_copy = family_sample_frame_copy.select_dtypes(include=['float64', 'int64']).copy()

# %% [markdown]
# L.

# %%
scaler = StandardScaler()

result = scaler.fit_transform(family_sample_frame_copy.values)
standard_family_frame = pd.DataFrame(result, columns=family_sample_frame_copy.columns)
standard_family_frame
# Out:
#       Total Household Income  ...  Number of Motorcycle/Tricycle
# 0                  -0.041195  ...                       1.282854
# 1                  -0.326742  ...                      -0.516477
# 2                  -0.226220  ...                      -0.516477
# 3                   0.912624  ...                       1.282854
# 4                  -0.373187  ...                      -0.516477
# ...                      ...  ...                            ...
# 8304               -0.484068  ...                      -0.516477
# 8305               -0.173835  ...                      -0.516477
# 8306               -0.228298  ...                      -0.516477
# 8307               -0.382324  ...                      -0.516477
# 8308               -0.547024  ...                      -0.516477
#
# [8309 rows x 45 columns]

# %% [markdown]
# M.

# %%
from sklearn.decomposition import PCA

pca_family = PCA(n_components=2)
principalComponents_family = pca_family.fit_transform(x)

principal_family_frame = pd.DataFrame(data = principalComponents_family, columns = ['principal component 1', 'principal component 2'])
principal_family_frame.tail(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-79cfefc59bd6> in <module>()
#       2
#       3 pca_family = PCA(n_components=2)
# ----> 4 principalComponents_family = pca_family.fit_transform(x)
#       5
#       6 principal_family_frame = pd.DataFrame(data = principalComponents_family, columns = ['principal component 1', 'principal component 2'])
#
# NameError: name 'x' is not defined

# %% [markdown]
# N

# %% [markdown]
# O

# %%
columns = ['Total Household Income','Region','Total Food Expenditure','Main Source of Income','Total Income from Entrepreneurial Acitivites','Household Head Sex','Household Head Age','Household Head Marital Status']
new_frame2 = family_sample_frame[columns]

# %% [markdown]
# EXPLANATION
#
# PART 1
# I imported the required libraries and used the read excel for the excel file in pandas. I searched for the missing values in the dataset and used the fill function to replace them with both the mean and mode which was determined by the mean and the mode function in pandas. After replacing the values I then printed the details of the frame and printed the first 20 records of the dataset.
# I then split the dataset into 30percent for the sample frame which I then determined the unique values with the unique function in pandas. I also determined the amount added to the customer on a monthly basis by looking the current date which goes the same for the next letter. The code for the final one is largely the same as the prvious 2 and all you need to do is replace the parameters.
#
#
# PART 2
#
# I imported the required libraries for the process. I then
# used the fill function of pandas to fill the missing values in the data set
# with the means and modes required. Showed the first 20 rows and split the data into 20% for a sample.
# I then created 4 bins to categroize the data using cut function of pandas and printed their frequencies. I also created another 5 bins based on the household age and allow the programe to automatically determine them.
# I then created a copy of the sample data frame and updated its features to be numerical as well as standardized the values of the remaining features using standard scaler.
